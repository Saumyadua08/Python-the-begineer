# %%
import numpy as np
arr= np.array('one')    
arr
# Out:
# array('one', dtype='<U3')

# %%
arr.ndim   # Zero dimensional array
# Out:
# 0

# %%
a=np.array([1,2,3,4])
a
# Out:
# array([1, 2, 3, 4])

# %%
a.ndim     # one dimensional array
# Out:
# 1

# %%
a.shape    # means it has 4 columns and 1 row
# Out:
# (4,)

# %%
a.size     # Total number of elements
# Out:
# 4

# %%
# Indexing
a[3]
# Out:
# 4

# %%
a[2] + a[1]
# Out:
# 5

# %%
# Slicing
a[2:]
# Out:
# array([3, 4])

# %%
b=np.array([[1,2,3],[4,5,6]])
b
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
b.ndim    # Two dimensional array
# Out:
# 2

# %%
b.shape   # Two rows and three columns
# Out:
# (2, 3)

# %%
b.size   # Matrix total elements
# Out:
# 6

# %%
# Indexing(2D)
b[0,1]
# Out:
# 2

# %%
# Slicing(2D)
b[1:,1:]
# Out:
# array([[5, 6]])

# %%
# np- numpy     random- package    randint- library
d=np.random.randint(0,10,6)     # any 6 random numbers between 0 to 10
d
# Out:
# array([2, 0, 8, 1, 1, 6])

# %%
e= np.random.randint(0,10, size=(2,2))   # 2D random matrix
e
# Out:
# array([[2, 5],
#        [4, 8]])

# %%
d.reshape(2,3)   # Reshape existing 1D into 2D
# Out:
# array([[4, 2, 2],
#        [5, 4, 4]])

# %%
d   # Our array is back to normal, that means reshaping done was not permanent change
# Out:
# array([4, 2, 2, 5, 4, 4])

# %%
# Let's store the reshaped array in variable d to make it permanent
d=d.reshape(2,3)

# %%
d               #voila!
# Out:
# array([[4, 2, 2],
#        [5, 4, 4]])

# %%
d.dtype      # int 64 means in d we can store 64bits integers
# Out:
# dtype('int64')

# %%
d.astype('float32')   # changing the type into float 32bits
# Out:
# array([[4., 2., 2.],
#        [5., 4., 4.]], dtype=float32)

# %%
x= np.ones(5)     # White colour
x                 # ones give float output
# Out:
# array([1., 1., 1., 1., 1.])

# %%
y= np.zeros(5)  # black colour
y               # Float output
# Out:
# array([0., 0., 0., 0., 0.])

# %%
z= np.zeros([2,2])   # 2D matrix
z
# Out:
# array([[0., 0.],
#        [0., 0.]])

# %%
import pandas as pd
df= pd.read_csv("/content/drive/MyDrive/Colab Notebooks/ML notebooks/train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Important, using
f1= np.sum((df['Sex']=='female')&(df['Survived']==1))
f0= np.sum((df['Sex']=='female')&(df['Survived']==0))
m1= np.sum((df['Sex']=='male')&(df['Survived']==1))
m0= np.sum((df['Sex']=='male')&(df['Survived']==0))
print(f1)
print(f0)
print(m1)
print(m0)
